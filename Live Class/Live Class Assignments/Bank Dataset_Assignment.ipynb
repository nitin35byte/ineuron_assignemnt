# %%
#sunny.savita@ineuron.ai
import pandas as pd

# %%
df = pd.read_csv("bank-full.csv",sep=";")
df.head(4)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no

# %% [markdown]
# ### how many campaign available in this dataset

# %%
df['campaign'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  6,  7,  8,  9, 10, 11, 12, 13, 19, 14, 24, 16,
#        32, 18, 22, 15, 17, 25, 21, 43, 51, 63, 41, 26, 28, 55, 50, 38, 23,
#        20, 29, 31, 37, 30, 46, 27, 58, 33, 35, 34, 36, 39, 44],
#       dtype=int64)

# %%
df.groupby('campaign')['campaign'].count()
# Out:
# campaign
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 24       20
# 25       22
# 26       13
# 27       10
# 28       16
# 29       16
# 30        8
# 31       12
# 32        9
# 33        6
# 34        5
# 35        4
# 36        4
# 37        2
# 38        3
# 39        1
# 41        2
# 43        3
# 44        1
# 46        1
# 50        2
# 51        1
# 55        1
# 58        1
# 63        1
# Name: campaign, dtype: int64

# %% [markdown]
# ### 2. how many users do we have with housing and personal loan .

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df['housing']== 'yes'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Name: housing, Length: 45211, dtype: bool

# %%
housing = df[df['housing']== 'yes']
housing
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 5       35    management   married   tertiary      no      231     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45191   75       retired  divorced   tertiary      no     3810     yes   no
# 45194   59    management   married   tertiary      no      138     yes  yes
# 45197   36    management    single  secondary      no     1511     yes   no
# 45199   34   blue-collar    single  secondary      no     1475     yes   no
# 45200   38    technician   married  secondary      no      557     yes   no
#
# ...

# %%
housing['loan'] == 'yes'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 5        False
#          ...
# 45191    False
# 45194     True
# 45197    False
# 45199    False
# 45200    False
# Name: loan, Length: 25130, dtype: bool

# %%
housing[housing['loan'] == 'yes']
# Out:
#        age           job  marital  education default  balance housing loan  \
# 2       33  entrepreneur  married  secondary      no        2     yes  yes
# 6       28    management   single   tertiary      no      447     yes  yes
# 20      28   blue-collar  married  secondary      no      723     yes  yes
# 22      32   blue-collar   single    primary      no       23     yes  yes
# 24      40       retired  married    primary      no        0     yes  yes
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 45103   33        admin.  married  secondary      no       51     yes  yes
# 45108   36    technician  married   tertiary      no      844     yes  yes
# 45122   40  entrepreneur   single   tertiary      no      262     yes  yes
# 45151   47    management   single   tertiary      no      311     yes  yes
# 45194   59    management  married   tertiary      no      138     yes  yes
#
# ...

# %%
len(housing[housing['loan'] == 'yes'])
# Out:
# 4367

# %% [markdown]
# ### 3.how many person do we have whose age is 60+ .

# %%
df[df['age']>60]
# Out:
#        age          job   marital  education default  balance housing loan  \
# 199     61  blue-collar  divorced    primary      no     1428     yes   no
# 575     61      retired   married  secondary      no      195     yes  yes
# 1233    61  blue-collar   married    primary      no      734     yes   no
# 2435    61      retired   married    primary      no     1060     yes   no
# 2992    61      retired   married  secondary      no     4248     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 45191   75      retired  divorced   tertiary      no     3810     yes   no
# 45195   68      retired   married  secondary      no     1146      no   no
# 45204   73      retired   married  secondary      no     2850      no   no
# 45207   71      retired  divorced    primary      no     1729      no   no
# 45208   72      retired   married  secondary      no     5715      no   no
#
# ...

# %%
len(df[df['age']>60])
# Out:
# 1188

# %% [markdown]
# ### 4. In which month we have targeted most of customer

# %%
df['month']
# Out:
# 0        may
# 1        may
# 2        may
# 3        may
# 4        may
#         ...
# 45206    nov
# 45207    nov
# 45208    nov
# 45209    nov
# 45210    nov
# Name: month, Length: 45211, dtype: object

# %%
Targeted = df.groupby('month')['month'].count()
Targeted
# Out:
# month
# apr     2932
# aug     6247
# dec      214
# feb     2649
# jan     1403
# jul     6895
# jun     5341
# mar      477
# may    13766
# nov     3970
# oct      738
# sep      579
# Name: month, dtype: int64

# %%
type(Targeted)
# Out:
# pandas.core.series.Series

# %%
Targeted.sort_values(ascending= False)
# Out:
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %% [markdown]
# ### 5. which mode of call is giving you more result

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.groupby('contact')['contact'].count()
# Out:
# contact
# cellular     29285
# telephone     2906
# unknown      13020
# Name: contact, dtype: int64

# %% [markdown]
# ### 6. how many enterpeures do we have in this list

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df[df['job'] == 'entrepreneur']
# Out:
#        age           job   marital  education default  balance housing loan  \
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 7       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 27      52  entrepreneur   married  secondary      no      113     yes  yes
# 55      38  entrepreneur    single   tertiary      no      243      no  yes
# 94      57  entrepreneur  divorced  secondary      no      -37      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45122   40  entrepreneur    single   tertiary      no      262     yes  yes
# 45140   63  entrepreneur   married  secondary      no     3904      no   no
# 45155   44  entrepreneur   married   tertiary      no      121      no   no
# 45175   38  entrepreneur    single  secondary      no     2543      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
len(df[df['job'] == 'entrepreneur'])
# Out:
# 1487

# %% [markdown]
# ### 7. how many customers do we have with negative balance

# %%
df['balance']<0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Name: balance, Length: 45211, dtype: bool

# %%
df[df['balance']<0]
# Out:
#        age          job   marital  education default  balance housing loan  \
# 25      44       admin.   married  secondary      no     -372     yes   no
# 28      46   management    single  secondary      no     -246     yes   no
# 36      25  blue-collar   married  secondary      no       -7     yes   no
# 37      53   technician   married  secondary      no       -3      no   no
# 45      36       admin.    single    primary      no     -171     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44626   31     services    single  secondary      no     -205      no   no
# 44629   28  blue-collar    single  secondary      no      -46     yes   no
# 44836   33  blue-collar   married    primary      no     -195      no   no
# 44908   48   management  divorced   tertiary      no     -130     yes   no
# 44964   21  blue-collar    single    primary      no      -42      no   no
#
# ...

# %% [markdown]
# ### 8. prepare a group of data based on education level .

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.groupby('education')

# %%
data = df.groupby('education').size().index
data
# Out:
# Index(['primary', 'secondary', 'tertiary', 'unknown'], dtype='object', name='education')

# %%
data[1]
# Out:
# 'secondary'

# %%
df.groupby('education').get_group(data[0])
# Out:
#        age          job   marital education default  balance housing loan  \
# 8       58      retired   married   primary      no      121     yes   no
# 15      51      retired   married   primary      no      229     yes   no
# 17      57  blue-collar   married   primary      no       52     yes   no
# 18      60      retired   married   primary      no       60     yes   no
# 22      32  blue-collar    single   primary      no       23     yes  yes
# ...    ...          ...       ...       ...     ...      ...     ...  ...
# 45152   61    housemaid   married   primary      no      182      no   no
# 45154   63      retired   married   primary      no     3738      no   no
# 45170   19      student    single   primary      no      245      no   no
# 45183   70      retired   married   primary      no      324      no   no
# 45207   71      retired  divorced   primary      no     1729      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
