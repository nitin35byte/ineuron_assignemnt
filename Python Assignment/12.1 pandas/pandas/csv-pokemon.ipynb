# %%
import pandas as pd
import numpy as np

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
google = pd.read_csv("google_stock_price.csv", usecols = ["Stock Price"], squeeze = True)
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
google = pd.read_csv("google_stock_price.csv", usecols = ["Stock Price"], squeeze = True)

# %%
google.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
google = pd.read_csv("google_stock_price.csv",  squeeze = True)

# %%
len(pokemon)
# Out:
# 721

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
sorted(pokemon)
sorted(google)
# Out:
# [49.95,
#  50.07,
#  50.12,
#  50.7,
#  50.74,
#  50.95,
#  51.1,
#  51.1,
#  51.13,
#  52.38,
#  52.61,
#  52.95,
#  53.02,
#  53.7,
#  53.9,
#  54.1,
#  54.65,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  58.86,
#  59.07,
#  59.13,
#  59.62,
#  59.86,
#  60.35,
#  63.37,
#  64.74,
#  65.47,
#  66.22,
#  67.46,
#  67.56,
#  68.47,
#  68.63,
#  68.8,
#  69.12,
#  69.36,
#  70.17,
#  70.38,
#  70.93,
#  71.98,
#  73.9,
#  74.51,
#  74.62,
#  82.47,
#  83.68,
#  83.69,
#  83.85,
#  84.27,
#  84.59,
#  84.62,
#  84.91,
#  85.14,
#  85.63,
#  85.74,
#  86.13,
#  86.16,
#  86.19,
#  86.19,
#  86.63,
#  87.29,
#  87.41,
#  87.71,
#  88.06,
#  88.15,
#  88.47,
#  88.81,
#  89.21,
#  89.22,
#  89.26,
#  89.4,
#  89.54,
#  89.56,
#  89.61,
#  89.61,
#  89.7,
#  89.8,
#  89.89,
#  89.9,
#  89.93,
#  89.93,
#  89.95,
#  90.11,
#  90.13,
#  90.16,
#  90.27,
#  90.35,
#  90.43,
#  90.58,
#  90.62,
#  90.81,
#  90.9,
#  90.91,
#  91.42,
#  91.78,
#  92.26,
#  92.34,
#  92.41,
#  92.42,
#  92.5,
# ...

# %%
list(pokemon)
list(google)
# Out:
# [50.12,
#  54.1,
#  54.65,
#  52.38,
#  52.95,
#  53.9,
#  53.02,
#  50.95,
#  51.13,
#  50.07,
#  50.7,
#  49.95,
#  50.74,
#  51.1,
#  51.1,
#  52.61,
#  53.7,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  59.62,
#  58.86,
#  59.13,
#  60.35,
#  59.86,
#  59.07,
#  63.37,
#  65.47,
#  64.74,
#  66.22,
#  67.46,
#  69.12,
#  68.47,
#  69.36,
#  68.8,
#  67.56,
#  68.63,
#  70.38,
#  70.93,
#  71.98,
#  74.51,
#  73.9,
#  70.17,
#  74.62,
#  86.13,
#  93.61,
#  90.81,
#  92.89,
#  96.55,
#  95.22,
#  97.92,
#  97.34,
#  95.74,
#  92.26,
#  84.59,
#  86.19,
#  84.27,
#  83.85,
#  91.42,
#  90.91,
#  92.34,
#  86.19,
#  86.16,
#  83.69,
#  84.62,
#  82.47,
#  83.68,
#  87.29,
#  89.61,
#  90.43,
#  90.9,
#  89.89,
#  89.61,
#  90.11,
#  88.06,
#  85.63,
#  84.91,
#  86.63,
#  85.74,
#  85.14,
#  89.26,
#  89.8,
#  88.15,
#  89.95,
#  92.42,
#  91.78,
#  93.06,
#  93.86,
#  95.86,
#  96.28,
#  96.35,
#  98.7,
#  96.3,
#  101.25,
#  97.15,
#  96.66,
#  94.18,
#  96.83,
#  97.43,
#  96.67,
# ...

# %%
dict(google)
# Out:
# {0: 50.12,
#  1: 54.1,
#  2: 54.65,
#  3: 52.38,
#  4: 52.95,
#  5: 53.9,
#  6: 53.02,
#  7: 50.95,
#  8: 51.13,
#  9: 50.07,
#  10: 50.7,
#  11: 49.95,
#  12: 50.74,
#  13: 51.1,
#  14: 51.1,
#  15: 52.61,
#  16: 53.7,
#  17: 55.69,
#  18: 55.94,
#  19: 56.93,
#  20: 58.69,
#  21: 59.62,
#  22: 58.86,
#  23: 59.13,
#  24: 60.35,
#  25: 59.86,
#  26: 59.07,
#  27: 63.37,
#  28: 65.47,
#  29: 64.74,
#  30: 66.22,
#  31: 67.46,
#  32: 69.12,
#  33: 68.47,
#  34: 69.36,
#  35: 68.8,
#  36: 67.56,
#  37: 68.63,
#  38: 70.38,
#  39: 70.93,
#  40: 71.98,
#  41: 74.51,
#  42: 73.9,
#  43: 70.17,
#  44: 74.62,
#  45: 86.13,
#  46: 93.61,
#  47: 90.81,
#  48: 92.89,
#  49: 96.55,
#  50: 95.22,
#  51: 97.92,
#  52: 97.34,
#  53: 95.74,
#  54: 92.26,
#  55: 84.59,
#  56: 86.19,
#  57: 84.27,
#  58: 83.85,
#  59: 91.42,
#  60: 90.91,
#  61: 92.34,
#  62: 86.19,
#  63: 86.16,
#  64: 83.69,
#  65: 84.62,
#  66: 82.47,
#  67: 83.68,
#  68: 87.29,
#  69: 89.61,
#  70: 90.43,
#  71: 90.9,
# ...

# %%
max(google)
# Out:
# 782.22

# %%
pokemon.values
google.values
# Out:
# array([ 50.12,  54.1 ,  54.65, ..., 773.18, 771.61, 782.22])

# %%
pokemon.index
google.index
# Out:
# RangeIndex(start=0, stop=3012, step=1)

# %%
pokemon.dtype
google.dtype
# Out:
# dtype('float64')

# %%
pokemon.is_unique
google.is_unique
# Out:
# False

# %%
pokemon.ndim
google.ndim
# Out:
# 1

# %%
pokemon.shape
google.shape
# Out:
# (3012,)

# %%
pokemon.size
google.size
# Out:
# 3012

# %%
pokemon.name = "Pocket Monsters"

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: poket Monsters, dtype: object

# %%
pokemon.sort_values().head()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
# Name: poket Monsters, dtype: object

# %%
pokemon.sort_values(ascending = False).tail()
# Out:
# 680    Aegislash
# 616     Accelgor
# 358        Absol
# 62          Abra
# 459    Abomasnow
# Name: Pokemon, dtype: object

# %%
google.sort_values(ascending = False).head(2)
# Out:
# 3011    782.22
# 2859    776.60
# Name: Stock Price, dtype: float64

# %%
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
#inplacememnt parameter
google = google.sort_values()
google.head(3)
# Out:
# 11    49.95
# 9     50.07
# 0     50.12
# Name: Stock Price, dtype: float64

# %%
google.sort_values(ascending = False, inplace = True)

# %%
google.head(3)
# Out:
# 3011    782.22
# 2859    776.60
# 3009    773.18
# Name: Stock Price, dtype: float64

# %%
pokemon.sort_values(ascending = False)
# Out:
# 717      Zygarde
# 633     Zweilous
# 40         Zubat
# 569        Zorua
# 570      Zoroark
#          ...
# 680    Aegislash
# 616     Accelgor
# 358        Absol
# 62          Abra
# 459    Abomasnow
# Name: Pokemon, Length: 721, dtype: object

# %%
#Index
pokemon.sort_index(ascending= True)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
pokemon = pd.read_csv("pokemon.csv", usecols = ["Pokemon"], squeeze = True)
google = pd.read_csv("google_stock_price.csv", usecols = ["Stock Price"], squeeze = True)

# %%
100 in pokemon
4000 in google
# Out:
# False

# %%
pokemon[1]

pokemon[[100, 200, 300]]
# Out:
# 100    Electrode
# 200        Unown
# 300     Delcatty
# Name: Pokemon, dtype: object

# %%
pokemon[: 100]
# Out:
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
#          ...
# 95       Drowzee
# 96         Hypno
# 97        Krabby
# 98       Kingler
# 99       Voltorb
# Name: Pokemon, Length: 100, dtype: object

# %%
pd.read_csv("pokemon.csv")
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %%
#Label
pd.read_csv("pokemon.csv", index_col = "Pokemon", squeeze = True)
# Out:
# Pokemon
# Bulbasaur       Grass
# Ivysaur         Grass
# Venusaur        Grass
# Charmander       Fire
# Charmeleon       Fire
#                ...
# Yveltal          Dark
# Zygarde        Dragon
# Diancie          Rock
# Hoopa         Psychic
# Volcanion        Fire
# Name: Type, Length: 721, dtype: object

# %%
pokemon[0]
# Out:
# 'Bulbasaur'

# %%
pokemon["Pikachu":]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-275b6e6f260f> in <module>
# ----> 1 pokemon["Pikachu":]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     875             return self._get_values(key)
#     876
# --> 877         return self._get_with(key)
#     878
#     879     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     882             # _convert_slice_indexer to determine if this slice is positional
#     883             #  or label based, and if the latter, convert to positional
# --> 884             slobj = self.index._convert_slice_indexer(key, kind="getitem")
#     885             return self._slice(slobj)
#     886         elif isinstance(key, ABCDataFrame):
#
# ...

# %%
pokemon.reindex(index = ["Bulbasaur", "Digimon"])
# Out:
# Bulbasaur    NaN
# Digimon      NaN
# Name: Pokemon, dtype: object

# %%
x = round(5.76543, 2)
print(x)
# Out:
# 5.77

# %%
print(round(x,2))
# Out:
# 5.77

# %%
google.describe()
# Out:
# count    3012.000000
# mean      334.310093
# std       173.187205
# min        49.950000
# 25%       218.045000
# 50%       283.315000
# 75%       443.000000
# max       782.220000
# Name: Stock Price, dtype: float64

# %%
# Importing the necessary libraries -->
import pandas as pd
import numpy as np
 
# Seeding random data from numpy
np.random.seed(24)
 
# Making the DataFrame
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4),
                                 columns=list('BCDE'))], axis=1)
 

def color_df(val):
    color='blue' if val <0 else 'green'
    return 'color: %s' %
    # DataFrame without any styling
#print("Original DataFrame:\n")
#print(df)
print("\nModified Stlying DataFrame:")
df.style.set_properties(**{'background-color': 'Black',
                           'color': 'green'})
# Out:
# Modified Stlying DataFrame:

# %%
df =pd.read_csv("revenue.csv")
df
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/16       985          122    499
# 1   1/2/16       738          788    534
# 2   1/3/16        14           20    933
# 3   1/4/16       730          904    885
# 4   1/5/16       114           71    253
# 5   1/6/16       936          502    497
# 6   1/7/16       123          996    115
# 7   1/8/16       935          492    886
# 8   1/9/16       846          954    823
# 9  1/10/16        54          285    216

# %%
def color_df(val):
    color='blue' if val >500 else 'green'
    return 'color: %s' % color
df.style.applymap(*{'color': 'green'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     203         Hooks into Jupyter notebook rich display system.
#     204         """
# --> 205         return self.render()
#     206
#     207     @doc(
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     617         * table_attributes
#     618         """
# --> 619         self._compute()
#     620         # TODO: namespace all the pandas keys
#     621         d = self._translate()
#
# ...

# %%
def color_df(val):
    color='blue' if val <0 else 'black'
    return 'color: %s' % color
df=pd.DataFrame(np.random.randn(4,4))
df.style.applymap(color_df)
#df.style.set_properties(**{'background-color': 'white'})
# Out:
# <style  type="text/css" >
# #T_45d2f_row0_col0,#T_45d2f_row0_col1,#T_45d2f_row0_col2,#T_45d2f_row0_col3,#T_45d2f_row1_col0,#T_45d2f_row1_col1,#T_45d2f_row1_col2,#T_45d2f_row2_col1,#T_45d2f_row2_col2,#T_45d2f_row3_col0{
#             color:  blue;
#         }#T_45d2f_row1_col3,#T_45d2f_row2_col0,#T_45d2f_row2_col3,#T_45d2f_row3_col1,#T_45d2f_row3_col2,#T_45d2f_row3_col3{
#             color:  black;
#         }</style><table id="T_45d2f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45d2f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45d2f_row0_col0" class="data row0 col0" >-1.205059</td>
# ...
