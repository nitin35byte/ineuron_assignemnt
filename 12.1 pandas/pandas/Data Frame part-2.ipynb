# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("employees.csv")
df.head(4)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance
# 3              True    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date']= pd.to_datetime(df['Start Date'])

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Last Login Time']= pd.to_datetime(df['Last Login Time'])
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-10 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Last Login Time']
# Out:
# 0      12:42 PM
# 1       6:53 AM
# 2      11:17 AM
# 3       1:00 PM
# 4       4:47 PM
#          ...
# 995     6:09 AM
# 996     6:30 AM
# 997    12:39 PM
# 998     4:45 PM
# 999     6:24 PM
# Name: Last Login Time, Length: 1000, dtype: object

# %%
df.isnull()
# Out:
#      First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 0         False   False       False            False   False    False
# 1         False   False       False            False   False    False
# 2         False   False       False            False   False    False
# 3         False   False       False            False   False    False
# 4         False   False       False            False   False    False
# ..          ...     ...         ...              ...     ...      ...
# 995       False    True       False            False   False    False
# 996       False   False       False            False   False    False
# 997       False   False       False            False   False    False
# 998       False   False       False            False   False    False
# 999       False   False       False            False   False    False
#
#      Senior Management   Team
# 0                False  False
# 1                False   True
# 2                False  False
# ...

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df["Gender"].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
df["Team"].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
df=pd.read_csv("employees.csv",parse_dates = ['Start Date','Last Login Time'])
#df['Start Date']= pd.to_datetime(df['Start Date'])
#df['Last Login Time']= pd.to_datetime(df['Last Login Time'])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(4)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-10 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance
# 3               True    Finance

# %%
a = [1, 2, 3]
b = a.copy()
a.append(4)
print(f'a is {a}')
print(f'b is {b}')
a is [1, 2, 3, 4]
b is [1, 2, 3]
# Out:
# a is [1, 2, 3, 4]
# b is [1, 2, 3]
# False

# %%
df=pd.read_csv("employees.csv",parse_dates = ['Start Date','Last Login Time'])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(4)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-16 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-16 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-16 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-16 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance
# 3               True    Finance

# %%
df[df["Gender"]=='Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-03-12 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-03-12 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-03-12 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-03-12 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-03-12 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-03-12 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df["Team"]=='Finance'
# Out:
# 0                 Marketing
# 1                       NaN
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %%
df[df["Team"]=='Finance']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-03-12 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-03-12 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-03-12 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-03-12 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-03-12 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-03-12 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-03-12 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-03-12 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
mask = df["Team"]=='Finance'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-03-12 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-03-12 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-03-12 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-03-12 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-03-12 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-03-12 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-03-12 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-03-12 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-12 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-03-12 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-03-12 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-03-12 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-03-12 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-03-12 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-03-12 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
mask1 = df["Team"] !="Senior Management"

# %%
df[mask1]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-12 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-03-12 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-03-12 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-12 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-12 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-03-12 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df[df["Salary"] >110000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-03-12 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2022-03-12 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-03-12 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2022-03-12 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2022-03-12 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2022-03-12 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-03-12 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-03-12 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-03-12 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
df[df["Salary"] <110000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-12 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-03-12 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2022-03-12 10:43:00   45906   11.598
# ..         ...     ...        ...                 ...     ...      ...
# 993       Tina  Female 1997-05-15 2022-03-12 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-03-12 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-03-12 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-03-12 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df[df["Salary"] <110000]
df[df["Bonus %"] <1.5]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2022-03-12 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2022-03-12 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2022-03-12 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2022-03-12 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2022-03-12 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2022-03-12 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2022-03-12 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2022-03-12 19:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19 2022-03-12 01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12 2022-03-12 01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27 2022-03-12 06:40:00   93847    1.085
# ...

# %%
dmask = df["Start Date"] <= "1985-01-01"

# %%
df[dmask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2022-03-12 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2022-03-12 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2022-03-12 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2022-03-12 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2022-03-12 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2022-03-12 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2022-03-12 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2022-03-12 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2022-03-12 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# ...

# %% [markdown]
# ## Filtering data with more than one conditon(AND)

# %%
a = df["Gender"] == "Male"

b = df["Team"] == "Marketing"

df[a & b]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2022-03-12 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2022-03-12 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2022-03-12 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2022-03-12 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2022-03-12 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2022-03-12 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2022-03-12 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2022-03-12 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2022-03-12 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2022-03-12 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2022-03-12 09:45:00   55281    4.935
# ...

# %% [markdown]
# ## Filtering data with more than one conditon(OR)

# %%
c = df["Senior Management"]

d = df["Start Date"] < "1990-01-01"

df[c  | d]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-03-12 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-03-12 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-03-12 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-03-12 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-03-12 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-03-12 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-03-12 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-03-12 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-03-12 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2022-03-12 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
e = df["First Name"] == "Robert"
f = df["Team"] == "Client Services"
g=  df["Start Date"] >"2016-06-01"

df[(e & f) | g]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-03-12 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-03-12 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-03-12 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-03-12 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
data= pd.DataFrame(df[(e & f) | g])

# %%
data
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-03-12 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-03-12 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-03-12 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-03-12 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ## .isin() Method

# %%
df=pd.read_csv("employees.csv",parse_dates = ['Start Date','Last Login Time'])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(4)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-03-16 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-03-16 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-03-16 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-03-16 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance
# 3               True    Finance

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-03-16 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-03-16 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-03-16 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-03-16 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-03-16 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-03-16 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-03-16 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-03-16 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-03-16 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-03-16 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
mask = df["Team"].isin(["Marketing","Legal","Sales","Product"])

# %%
df1 = pd.DataFrame(mask)
df1
# Out:
#       Team
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 995  False
# 996  False
# 997   True
# 998  False
# 999   True
#
# [1000 rows x 1 columns]

# %%
mask5 = df["Team"].isnull()
df[mask5]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-03-16 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-03-16 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-03-16 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-03-16 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-03-16 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-03-16 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-03-16 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-03-16 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-03-16 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-03-16 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-03-16 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-03-16 06:06:00   66067   10.957
# ...

# %%
mask5 = df["Gender"].notnull()
df[mask5]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
pd.DataFrame(df[mask5])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# ## Between () Method

# %%
df[df["Salary"].between(60000 ,70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 6         Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# 10      Louise  Female  8/12/1980         9:01 AM   63241   15.132
# 20        Lois     NaN  4/22/1995         7:18 PM   64714    4.934
# 41   Christine     NaN  6/28/2015         1:08 AM   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female  9/25/1989         1:31 AM   68164   18.393
# 970      Alice  Female   9/3/1988         8:54 PM   63571   15.397
# 974      Harry    Male  8/30/2011         6:31 PM   67656   16.455
# 978       Sean    Male  1/17/1983         2:23 PM   66146   11.178
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# ...

# %%
df[df["Bonus %"].between(2.0 ,5.0)]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 20        Lois     NaN   4/22/1995         7:18 PM   64714    4.934
# 40     Michael    Male  10/10/2008        11:25 AM   99283    2.665
# 49       Chris     NaN   1/24/1980        12:13 PM  113590    3.055
# 60       Paula     NaN  11/23/2005         2:01 PM   48866    4.271
# ..         ...     ...         ...             ...     ...      ...
# 943      Wayne    Male    9/8/2006        11:09 AM   67471    2.728
# 961    Antonio     NaN   6/18/1989         9:37 PM  103050    3.050
# 976     Denise  Female  10/19/1992         5:42 AM  137954    4.195
# 989     Justin     NaN   2/10/1991         4:58 PM   38344    3.794
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution
# ...

# %%
df[["Salary"]

# %% [markdown]
# ## .Duplicated() Method

# %%
df=pd.read_csv("employees.csv",parse_dates = ['Start Date','Last Login Time'])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace= True)
df.head(4)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-03-16 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-03-16 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-03-16 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-03-16 19:39:00   63126   18.424
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services

# %%
df[df["First Name"].duplicated()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-03-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-16 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2022-03-16 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-03-16 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-16 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-16 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
df[df["First Name"].duplicated(keep = "last")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-16 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-03-16 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-03-16 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2022-03-16 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2022-03-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-16 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df[df["First Name"].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-03-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-03-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-03-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-03-16 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-03-16 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-03-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-03-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-03-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-03-16 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-03-16 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %% [markdown]
# ## Unique and nunique method

# %%
df["Gender"].unique()

df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique(dropna = False)
# Out:
# 11

# %%
df["Team"].nunique(dropna = True)
# Out:
# 10
