# %%
pip install cufflinks
# Out:
# ...
#
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68724 sha256=7a5f715597946db958ce75cd93fbf12a57dab0e8c8d527165dde99ff18bd9a79
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\6b\76\62\6da97734911ffcbdd559fd1a3f28526321f0ae699182a23866
# Successfully built cufflinks
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#creating data 
np.random.randn(1000)

# %%
df = pd.DataFrame(np.random.randn(1000) ,columns=['data'], index = pd.date_range('2022/3/26' , periods = 1000))

# %%
df
# Out:
#                 data
# 2022-03-26 -0.687699
# 2022-03-27  1.439163
# 2022-03-28 -1.910726
# 2022-03-29  0.472069
# 2022-03-30 -1.093936
# ...              ...
# 2024-12-15 -0.019853
# 2024-12-16 -0.568660
# 2024-12-17  0.472530
# 2024-12-18 -0.022262
# 2024-12-19 -0.704167
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.drop('Id' ,axis = 1 , inplace = True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#line plot
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20 ,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df.iloc[[2]].plot(kind = 'bar', figsize = (20 ,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[[2]].plot(kind = 'barh', figsize = (20 ,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (20 ,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'hist', figsize = (20 ,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['SepalLengthCm'].plot(kind = 'hist' , orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df.iloc[5:11].plot(kind = 'hist', figsize = (20 ,10))

# %%
df.hist( figsize = (20 ,10) ,color = 'g' ,alpha = 0.5)
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
#box i used for find the outliers data 

df.plot(kind = 'box' ,figsize = (20,10), color ={"boxes":'g' ,'whiskers':'r'})
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.plot(kind = 'area' , figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area' , figsize = (20,10),alpha = 0.5,stacked = False)
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (20,10),alpha = 0.5,stacked = False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'SepalLengthCm'  ,y = 'PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x = 'SepalLengthCm'  ,y = 'PetalWidthCm' , c = 'SepalWidthCm' , s =df['PetalWidthCm']*500 )
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.plot.hexbin(x = 'SepalLengthCm'  ,y = 'PetalWidthCm' , gridsize = 10 , C = 'SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
df.iloc[0]
# Out:
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
df1 = df.drop(columns ='Species'). iloc[0]

# %%
df1. plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=ef14ab6189b02e1e9df5e1ba6b96718c3337de7381f3553b3edbce388b04145e
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iplot()
# Out:
# <div>                            <div id="0f15c628-24ea-4df6-ae7c-2658b878ca6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(x = 'SepalLengthCm' , y = 'PetalLengthCm'  , mode = 'markers' , kind = 'scatter')
# Out:
# <div>                            <div id="59f013d7-d813-4a05-b0cb-97d00e515899" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter' , mode = 'markers' , size = 10)
# Out:
# <div>                            <div id="69d1a058-6a39-482b-be7f-03061b8c0b83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter' , mode = 'markers' , size = 3)
# Out:
# <div>                            <div id="5020f862-bf2d-408c-a9ac-3a95ee6b37f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind ='bubble' , x = 'SepalLengthCm' , y = 'PetalLengthCm' , size = 'SepalWidthCm')
# Out:
# <div>                            <div id="e950f2d7-107c-4e48-be29-b8f5699fbede" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="7554ccf2-df59-47e1-8740-cc978b4c9c63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(5).iplot(kind = 'scatter3d' , x = 'SepalLengthCm' , y= 'SepalWidthCm' , z = 'SepalWidthCm')
# Out:
# <div>                            <div id="c4fb04ad-6f06-411e-b75b-2b6a741f6d82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter3d' , x = 'SepalLengthCm' , y= 'SepalWidthCm' , z = 'PetalLengthCm')
# Out:
# <div>                            <div id="4135f686-cf61-4686-a972-6e86553e6051" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind ='bubble3d' , x = 'SepalLengthCm' , y = 'PetalLengthCm' ,z = 'PetalLengthCm', size = 'SepalWidthCm')
# Out:
# <div>                            <div id="534cb65a-686a-469f-a06b-701eb29689ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#Home work
try to explore map graph and try to show and example(2-3)

# %%
def find_even_nums(n):
    x = [i for i in range (2,n+1) if n % 2 == 0]
    return x

# %%
print(find_even_nums(8))
# Out:
# [2, 3, 4, 5, 6, 7, 8]
